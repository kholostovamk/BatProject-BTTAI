# %%
# !ls
# Out:
# sample_data

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %ls /content/gdrive/Shareddrives/BTTAI/map_data.csv
# Out:
# /content/gdrive/Shareddrives/BTTAI/map_data.csv

# %%
import numpy as np
import pandas as pd

df_map_data = pd.read_csv('/content/gdrive/Shareddrives/BTTAI/map_data.csv')

# %%
df_map_data
# Out:
#     country    stateprov       county determination release_date status_season
# 0       USA     Nebraska    Lancaster   Pd Positive       6/7/17       2016-17
# 1       USA     Nebraska        Dixon   Pd Positive       6/7/17       2016-17
# 2       USA     Nebraska         Cass  WNS Positive      3/15/17       2016-17
# 3       USA     Nebraska        Sarpy   WNS Suspect      3/15/17       2016-17
# 4       USA  Mississippi        Wayne   Pd Positive      4/24/17       2016-17
# ..      ...          ...          ...           ...          ...           ...
# 661     USA        Maine       Oxford  WNS Positive       1/1/11       2010-11
# 662     USA        Maine  Piscataquis   WNS Suspect       1/1/13       2012-13
# 663     USA    Wisconsin         Iron   WNS Suspect       1/1/16       2015-16
# 664     USA    Wisconsin      Douglas  WNS Positive       1/1/16       2015-16
# 665     USA   Washington         King  WNS Positive       1/1/16       2015-16
#
# [666 rows x 6 columns]

# %%
#df.loc based on status season?
import plotly.figure_factory as ff

import numpy as np
import pandas as pd

df_sample = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/laucnty16.csv')
df_sample['State FIPS Code'] = df_sample['State FIPS Code'].apply(lambda x: str(x).zfill(2))
df_sample['County FIPS Code'] = df_sample['County FIPS Code'].apply(lambda x: str(x).zfill(3))
df_sample['FIPS'] = df_sample['State FIPS Code'] + df_sample['County FIPS Code']

colorscale = ["#f7fbff","#ebf3fb","#deebf7","#d2e3f3","#c6dbef","#b3d2e9","#9ecae1",
              "#85bcdb","#6baed6","#57a0ce","#4292c6","#3082be","#2171b5","#1361a9",
              "#08519c","#0b4083","#08306b"]
endpts = list(np.linspace(1, 12, len(colorscale) - 1))
fips = df_sample['FIPS'].tolist()
values = df_sample['Unemployment Rate (%)'].tolist()

fig = ff.create_choropleth(
    fips=fips, values=values,
    binning_endpoints=endpts,
    colorscale=colorscale,
    show_state_data=False,
    show_hover=True, centroid_marker={'opacity': 0},
    asp=2.9, title='USA by Unemployment %',
    legend_title='% unemployed'
)

fig.layout.template = None
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-7c5791269a81> in <cell line: 19>()
#      17 values = df_sample['Unemployment Rate (%)'].tolist()
#      18
# ---> 19 fig = ff.create_choropleth(
#      20     fips=fips, values=values,
#      21     binning_endpoints=endpts,
#
# /usr/local/lib/python3.10/dist-packages/plotly/figure_factory/_county_choropleth.py in create_choropleth(fips, values, scope, binning_endpoints, colorscale, order, simplify_county, simplify_state, asp, show_hover, show_state_data, state_outline, county_outline, centroid_marker, round_legend_values, exponent_format, legend_title, **layout_options)
#     608     # ensure optional modules imported
#     609     if not _plotly_geo:
# --> 610         raise ValueError(
#     611             """
#     612 The create_choropleth figure factory requires the plotly-geo package.
#
# ValueError:
# ...

# %%
A = pd.merge(A,B,how='left',left_on='code1',right_on='code').drop(['code'], axis=1)

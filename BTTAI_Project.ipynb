# %% [markdown]
# Figuring out if all members can import and access data in shared drives

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %ls
# Out:
# drive/  sample_data/

# %%
# %ls /content/drive/
# Out:
# MyDrive/  Othercomputers/
